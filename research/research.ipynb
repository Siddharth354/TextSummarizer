# %%
1+1
# Out:
# 2

# %%
dict_info={"name":"Sid","lastname":"Gan"}

dict_info["name"]
# Out:
# 'Sid'

# %%
dict_info.name
# Out:
# 'Sid'

# %%
from box import ConfigBox
dict_info=ConfigBox({"name":"Sid","lastname":"Gan"})
dict_info.name
# Out:
# Collecting python-box
#   Using cached python_box-7.3.2-cp312-cp312-win_amd64.whl.metadata (8.3 kB)
# Using cached python_box-7.3.2-cp312-cp312-win_amd64.whl (1.2 MB)
# Installing collected packages: python-box
# Successfully installed python-box-7.3.2
# Note: you may need to restart the kernel to use updated packages.
# 'Sid'

# %%
def multiplication(x:int,y:int)-> int:
    return x*y

# %%
multiplication(2,3)
# Out:
# 6

# %%
multiplication(2,"3")
# Out:
# '33'

# %%
2*"3"
# Out:
# '33'

# %%
from ensure import ensure_annotations

@ensure_annotations
def multiplication(x:int,y:int)-> int:
    return x*y

# %%
multiplication(2, int("3"))
# Out:
# 6
